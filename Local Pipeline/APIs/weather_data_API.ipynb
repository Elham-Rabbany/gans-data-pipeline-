# %%
import pandas as pd
import requests
from datetime import datetime

# using colab secrets to store our passwords and keys
from google.colab import userdata
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 6
#       3 from datetime import datetime
#       5 # using colab secrets to store our passwords and keys
# ----> 6 from google.colab import userdata
#
# ModuleNotFoundError: No module named 'google.colab'

# %% [markdown]
# # Making the API call and viewing the json
#
# If you want to search for the city by name and country instead of latitude and longitude, try using the [Geocoding API](https://openweathermap.org/api/geocoding-api).

# %%
# Berlin
latitude = 52.520008
longitude = 13.404954

API_key = userdata.get('openWeatherApi')

# check out the docs for more info on making an api call https://openweathermap.org/forecast5
url = (f"https://api.openweathermap.org/data/2.5/forecast?lat={latitude}&lon={longitude}&appid={API_key}&units=metric")

response = requests.get(url)
json = response.json()

json
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1718204400,
#    'main': {'temp': 17.32,
#     'feels_like': 16.52,
#     'temp_min': 17.32,
#     'temp_max': 18.04,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 1011,
#     'humidity': 54,
#     'temp_kf': -0.72},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 25},
#    'wind': {'speed': 4.47, 'deg': 254, 'gust': 6.42},
#    'visibility': 10000,
#    'pop': 0.03,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-12 15:00:00'},
#   {'dt': 1718215200,
#    'main': {'temp': 16.25,
#     'feels_like': 15.31,
#     'temp_min': 15.89,
#     'temp_max': 16.25,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1011,
#     'humidity': 53,
#     'temp_kf': 0.36},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 53},
#    'wind': {'speed': 2.79, 'deg': 279, 'gust': 4.6},
#    'visibility': 10000,
#    'pop': 0.07,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-12 18:00:00'},
#   {'dt': 1718226000,
#    'main': {'temp': 12.2,
#     'feels_like': 11.3,
#     'temp_min': 12.2,
#     'temp_max': 12.2,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1012,
#     'humidity': 70,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 7},
#    'wind': {'speed': 2.33, 'deg': 270, 'gust': 4.78},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-06-12 21:00:00'},
#   {'dt': 1718236800,
#    'main': {'temp': 10.13,
#     'feels_like': 9.37,
#     'temp_min': 10.13,
#     'temp_max': 10.13,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1012,
#     'humidity': 83,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 30},
#    'wind': {'speed': 2.62, 'deg': 274, 'gust': 4.96},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-06-13 00:00:00'},
#   {'dt': 1718247600,
#    'main': {'temp': 9.06,
#     'feels_like': 7.65,
#     'temp_min': 9.06,
#     'temp_max': 9.06,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1013,
#     'humidity': 86,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 91},
#    'wind': {'speed': 2.59, 'deg': 285, 'gust': 5.11},
#    'visibility': 10000,
#    'pop': 0.04,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-13 03:00:00'},
#   {'dt': 1718258400,
#    'main': {'temp': 11.87,
#     'feels_like': 10.81,
#     'temp_min': 11.87,
#     'temp_max': 11.87,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1013,
#     'humidity': 65,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 95},
#    'wind': {'speed': 2.91, 'deg': 279, 'gust': 4.8},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-13 06:00:00'},
#   {'dt': 1718269200,
#    'main': {'temp': 15.15,
#     'feels_like': 13.97,
#     'temp_min': 15.15,
#     'temp_max': 15.15,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1013,
#     'humidity': 48,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 90},
#    'wind': {'speed': 3.34, 'deg': 257, 'gust': 5.08},
#    'visibility': 10000,
#    'pop': 0.02,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-13 09:00:00'},
#   {'dt': 1718280000,
#    'main': {'temp': 15.87,
#     'feels_like': 14.56,
#     'temp_min': 15.87,
#     'temp_max': 15.87,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1012,
#     'humidity': 40,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 94},
#    'wind': {'speed': 3.86, 'deg': 253, 'gust': 5.37},
#    'visibility': 10000,
#    'pop': 0.03,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-13 12:00:00'},
#   {'dt': 1718290800,
#    'main': {'temp': 16.53,
#     'feels_like': 15.34,
#     'temp_min': 16.53,
#     'temp_max': 16.53,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1012,
#     'humidity': 42,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 92},
#    'wind': {'speed': 3.7, 'deg': 288, 'gust': 4.44},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-13 15:00:00'},
#   {'dt': 1718301600,
#    'main': {'temp': 16.51,
#     'feels_like': 15.39,
#     'temp_min': 16.51,
#     'temp_max': 16.51,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1012,
#     'humidity': 45,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 67},
#    'wind': {'speed': 2.22, 'deg': 308, 'gust': 3.26},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-13 18:00:00'},
#   {'dt': 1718312400,
#    'main': {'temp': 13.06,
#     'feels_like': 11.86,
#     'temp_min': 13.06,
#     'temp_max': 13.06,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1012,
#     'humidity': 55,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 37},
#    'wind': {'speed': 2.21, 'deg': 118, 'gust': 3.08},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-06-13 21:00:00'},
#   {'dt': 1718323200,
#    'main': {'temp': 11.74,
#     'feels_like': 10.54,
#     'temp_min': 11.74,
#     'temp_max': 11.74,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1011,
#     'humidity': 60,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 60},
#    'wind': {'speed': 2.76, 'deg': 142, 'gust': 5.96},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-06-14 00:00:00'},
#   {'dt': 1718334000,
#    'main': {'temp': 11.65,
#     'feels_like': 10.44,
#     'temp_min': 11.65,
#     'temp_max': 11.65,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1010,
#     'humidity': 60,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.36, 'deg': 144, 'gust': 9.33},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-14 03:00:00'},
#   {'dt': 1718344800,
#    'main': {'temp': 13.83,
#     'feels_like': 12.78,
#     'temp_min': 13.83,
#     'temp_max': 13.83,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1009,
#     'humidity': 58,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.76, 'deg': 150, 'gust': 8.83},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-14 06:00:00'},
#   {'dt': 1718355600,
#    'main': {'temp': 20.1,
#     'feels_like': 19.26,
#     'temp_min': 20.1,
#     'temp_max': 20.1,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 1008,
#     'humidity': 42,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.19, 'deg': 164, 'gust': 5.78},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-14 09:00:00'},
#   {'dt': 1718366400,
#    'main': {'temp': 20.34,
#     'feels_like': 19.6,
#     'temp_min': 20.34,
#     'temp_max': 20.34,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1007,
#     'humidity': 45,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 98},
#    'wind': {'speed': 6.15, 'deg': 208, 'gust': 7.95},
#    'visibility': 10000,
#    'pop': 0.02,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-14 12:00:00'},
#   {'dt': 1718377200,
#    'main': {'temp': 17.94,
#     'feels_like': 17.46,
#     'temp_min': 17.94,
#     'temp_max': 17.94,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 1008,
#     'humidity': 64,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 98},
#    'wind': {'speed': 3.79, 'deg': 191, 'gust': 6.31},
#    'visibility': 10000,
#    'pop': 0.72,
#    'rain': {'3h': 0.22},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-14 15:00:00'},
#   {'dt': 1718388000,
#    'main': {'temp': 17.77,
#     'feels_like': 17.35,
#     'temp_min': 17.77,
#     'temp_max': 17.77,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1007,
#     'humidity': 67,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 86},
#    'wind': {'speed': 3.37, 'deg': 172, 'gust': 5.81},
#    'visibility': 10000,
#    'pop': 0.65,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-14 18:00:00'},
#   {'dt': 1718398800,
#    'main': {'temp': 15.2,
#     'feels_like': 14.92,
#     'temp_min': 15.2,
#     'temp_max': 15.2,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1007,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 83},
#    'wind': {'speed': 2.74, 'deg': 157, 'gust': 6.32},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-06-14 21:00:00'},
#   {'dt': 1718409600,
#    'main': {'temp': 13.58,
#     'feels_like': 13.24,
#     'temp_min': 13.58,
#     'temp_max': 13.58,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1006,
#     'humidity': 86,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 79},
#    'wind': {'speed': 2.55, 'deg': 168, 'gust': 5.53},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-06-15 00:00:00'},
#   {'dt': 1718420400,
#    'main': {'temp': 13.12,
#     'feels_like': 12.73,
#     'temp_min': 13.12,
#     'temp_max': 13.12,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1004,
#     'humidity': 86,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.74, 'deg': 161, 'gust': 6.93},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-15 03:00:00'},
#   {'dt': 1718431200,
#    'main': {'temp': 16.44,
#     'feels_like': 15.86,
#     'temp_min': 16.44,
#     'temp_max': 16.44,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 1002,
#     'humidity': 66,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.61, 'deg': 147, 'gust': 9.32},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-15 06:00:00'},
#   {'dt': 1718442000,
#    'main': {'temp': 21,
#     'feels_like': 20.64,
#     'temp_min': 21,
#     'temp_max': 21,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 1003,
#     'humidity': 57,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 6.43, 'deg': 225, 'gust': 8.53},
#    'visibility': 10000,
#    'pop': 0.36,
#    'rain': {'3h': 0.23},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-15 09:00:00'},
#   {'dt': 1718452800,
#    'main': {'temp': 15.31,
#     'feels_like': 15.3,
#     'temp_min': 15.31,
#     'temp_max': 15.31,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 1004,
#     'humidity': 92,
#     'temp_kf': 0},
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.2, 'deg': 185, 'gust': 10.98},
#    'visibility': 10000,
#    'pop': 0.98,
#    'rain': {'3h': 5.93},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-15 12:00:00'},
#   {'dt': 1718463600,
#    'main': {'temp': 18.38,
#     'feels_like': 18.13,
#     'temp_min': 18.38,
#     'temp_max': 18.38,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 1004,
#     'humidity': 71,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.04, 'deg': 226, 'gust': 8.46},
#    'visibility': 10000,
#    'pop': 0.8,
#    'rain': {'3h': 0.5},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-15 15:00:00'},
#   {'dt': 1718474400,
#    'main': {'temp': 18.02,
#     'feels_like': 17.57,
#     'temp_min': 18.02,
#     'temp_max': 18.02,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 1004,
#     'humidity': 65,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 2.09, 'deg': 231, 'gust': 4.71},
#    'visibility': 10000,
#    'pop': 0.66,
#    'rain': {'3h': 0.11},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-15 18:00:00'},
#   {'dt': 1718485200,
#    'main': {'temp': 15.28,
#     'feels_like': 14.9,
#     'temp_min': 15.28,
#     'temp_max': 15.28,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1006,
#     'humidity': 78,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 81},
#    'wind': {'speed': 2.62, 'deg': 189, 'gust': 7.09},
#    'visibility': 10000,
#    'pop': 0.42,
#    'rain': {'3h': 0.29},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-06-15 21:00:00'},
#   {'dt': 1718496000,
#    'main': {'temp': 13.21,
#     'feels_like': 12.81,
#     'temp_min': 13.21,
#     'temp_max': 13.21,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1006,
#     'humidity': 85,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 67},
#    'wind': {'speed': 1.58, 'deg': 221, 'gust': 1.77},
#    'visibility': 10000,
#    'pop': 0.22,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-06-16 00:00:00'},
#   {'dt': 1718506800,
#    'main': {'temp': 11.98,
#     'feels_like': 11.43,
#     'temp_min': 11.98,
#     'temp_max': 11.98,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1006,
#     'humidity': 84,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 46},
#    'wind': {'speed': 2.13, 'deg': 209, 'gust': 3.28},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-16 03:00:00'},
#   {'dt': 1718517600,
#    'main': {'temp': 16.4,
#     'feels_like': 15.51,
#     'temp_min': 16.4,
#     'temp_max': 16.4,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1007,
#     'humidity': 54,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 61},
#    'wind': {'speed': 3.84, 'deg': 226, 'gust': 8.22},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-16 06:00:00'},
#   {'dt': 1718528400,
#    'main': {'temp': 21.05,
#     'feels_like': 20.23,
#     'temp_min': 21.05,
#     'temp_max': 21.05,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1007,
#     'humidity': 39,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 9},
#    'wind': {'speed': 4.86, 'deg': 224, 'gust': 8.14},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-16 09:00:00'},
#   {'dt': 1718539200,
#    'main': {'temp': 22.53,
#     'feels_like': 21.83,
#     'temp_min': 22.53,
#     'temp_max': 22.53,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1007,
#     'humidity': 38,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 28},
#    'wind': {'speed': 4.86, 'deg': 226, 'gust': 7.86},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-16 12:00:00'},
#   {'dt': 1718550000,
#    'main': {'temp': 20.97,
#     'feels_like': 20.35,
#     'temp_min': 20.97,
#     'temp_max': 20.97,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1007,
#     'humidity': 47,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 94},
#    'wind': {'speed': 4.5, 'deg': 217, 'gust': 6.72},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-16 15:00:00'},
#   {'dt': 1718560800,
#    'main': {'temp': 19.83,
#     'feels_like': 19.25,
#     'temp_min': 19.83,
#     'temp_max': 19.83,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 1008,
#     'humidity': 53,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 89},
#    'wind': {'speed': 2.84, 'deg': 196, 'gust': 6.2},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-16 18:00:00'},
#   {'dt': 1718571600,
#    'main': {'temp': 16.94,
#     'feels_like': 16.41,
#     'temp_min': 16.94,
#     'temp_max': 16.94,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1009,
#     'humidity': 66,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 59},
#    'wind': {'speed': 2.49, 'deg': 201, 'gust': 6.2},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-06-16 21:00:00'},
#   {'dt': 1718582400,
#    'main': {'temp': 15.45,
#     'feels_like': 14.88,
#     'temp_min': 15.45,
#     'temp_max': 15.45,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1010,
#     'humidity': 70,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 76},
#    'wind': {'speed': 2.23, 'deg': 205, 'gust': 4.84},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-06-17 00:00:00'},
#   {'dt': 1718593200,
#    'main': {'temp': 14.49,
#     'feels_like': 13.93,
#     'temp_min': 14.49,
#     'temp_max': 14.49,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1010,
#     'humidity': 74,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 2.41, 'deg': 187, 'gust': 5.38},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-17 03:00:00'},
#   {'dt': 1718604000,
#    'main': {'temp': 18.68,
#     'feels_like': 18.14,
#     'temp_min': 18.68,
#     'temp_max': 18.68,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1010,
#     'humidity': 59,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 54},
#    'wind': {'speed': 3.62, 'deg': 188, 'gust': 6.55},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-17 06:00:00'},
#   {'dt': 1718614800,
#    'main': {'temp': 24.15,
#     'feels_like': 23.72,
#     'temp_min': 24.15,
#     'temp_max': 24.15,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1010,
#     'humidity': 42,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 13},
#    'wind': {'speed': 4.56, 'deg': 206, 'gust': 6.86},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-17 09:00:00'},
#   {'dt': 1718625600,
#    'main': {'temp': 27.38,
#     'feels_like': 26.84,
#     'temp_min': 27.38,
#     'temp_max': 27.38,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1009,
#     'humidity': 34,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 20},
#    'wind': {'speed': 4.88, 'deg': 207, 'gust': 7.57},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-06-17 12:00:00'}],
#  'city': {'id': 6545310,
#   'name': 'Mitte',
#   'coord': {'lat': 52.52, 'lon': 13.405},
#   'country': 'DE',
#   'population': 329078,
#   'timezone': 7200,
#   'sunrise': 1718160203,
#   'sunset': 1718220562}}

# %% [markdown]
# # Exploring the json
# Remember, if you want to know more about any of the information in the json, or you're unsure what a key is, check out the [open weather docs](https://openweathermap.org/forecast5).
#
# First, let's look at the keys

# %%
json.keys()
# Out:
# dict_keys(['cod', 'message', 'cnt', 'list', 'city'])

# %%
json["cod"]
# Out:
# '200'

# %%
json["message"]
# Out:
# 0

# %%
json["cnt"]
# Out:
# 40

# %%
json["list"]
# Out:
# [{'dt': 1718204400,
#   'main': {'temp': 17.32,
#    'feels_like': 16.52,
#    'temp_min': 17.32,
#    'temp_max': 18.04,
#    'pressure': 1009,
#    'sea_level': 1009,
#    'grnd_level': 1011,
#    'humidity': 54,
#    'temp_kf': -0.72},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'clouds': {'all': 25},
#   'wind': {'speed': 4.47, 'deg': 254, 'gust': 6.42},
#   'visibility': 10000,
#   'pop': 0.03,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2024-06-12 15:00:00'},
#  {'dt': 1718215200,
#   'main': {'temp': 16.25,
#    'feels_like': 15.31,
#    'temp_min': 15.89,
#    'temp_max': 16.25,
#    'pressure': 1012,
#    'sea_level': 1012,
#    'grnd_level': 1011,
#    'humidity': 53,
#    'temp_kf': 0.36},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 53},
#   'wind': {'speed': 2.79, 'deg': 279, 'gust': 4.6},
#   'visibility': 10000,
#   'pop': 0.07,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2024-06-12 18:00:00'},
#  {'dt': 1718226000,
#   'main': {'temp': 12.2,
#    'feels_like': 11.3,
#    'temp_min': 12.2,
#    'temp_max': 12.2,
#    'pressure': 1017,
#    'sea_level': 1017,
#    'grnd_level': 1012,
#    'humidity': 70,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'clouds': {'all': 7},
#   'wind': {'speed': 2.33, 'deg': 270, 'gust': 4.78},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2024-06-12 21:00:00'},
#  {'dt': 1718236800,
#   'main': {'temp': 10.13,
#    'feels_like': 9.37,
#    'temp_min': 10.13,
#    'temp_max': 10.13,
#    'pressure': 1018,
#    'sea_level': 1018,
#    'grnd_level': 1012,
#    'humidity': 83,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'clouds': {'all': 30},
#   'wind': {'speed': 2.62, 'deg': 274, 'gust': 4.96},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2024-06-13 00:00:00'},
#  {'dt': 1718247600,
#   'main': {'temp': 9.06,
#    'feels_like': 7.65,
#    'temp_min': 9.06,
#    'temp_max': 9.06,
#    'pressure': 1018,
#    'sea_level': 1018,
#    'grnd_level': 1013,
#    'humidity': 86,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 91},
#   'wind': {'speed': 2.59, 'deg': 285, 'gust': 5.11},
#   'visibility': 10000,
#   'pop': 0.04,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2024-06-13 03:00:00'},
#  {'dt': 1718258400,
#   'main': {'temp': 11.87,
#    'feels_like': 10.81,
#    'temp_min': 11.87,
#    'temp_max': 11.87,
#    'pressure': 1018,
#    'sea_level': 1018,
#    'grnd_level': 1013,
#    'humidity': 65,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 95},
#   'wind': {'speed': 2.91, 'deg': 279, 'gust': 4.8},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2024-06-13 06:00:00'},
#  {'dt': 1718269200,
#   'main': {'temp': 15.15,
#    'feels_like': 13.97,
#    'temp_min': 15.15,
#    'temp_max': 15.15,
#    'pressure': 1018,
#    'sea_level': 1018,
#    'grnd_level': 1013,
#    'humidity': 48,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 90},
#   'wind': {'speed': 3.34, 'deg': 257, 'gust': 5.08},
#   'visibility': 10000,
#   'pop': 0.02,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2024-06-13 09:00:00'},
#  {'dt': 1718280000,
#   'main': {'temp': 15.87,
#    'feels_like': 14.56,
#    'temp_min': 15.87,
#    'temp_max': 15.87,
#    'pressure': 1017,
#    'sea_level': 1017,
#    'grnd_level': 1012,
#    'humidity': 40,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 94},
#   'wind': {'speed': 3.86, 'deg': 253, 'gust': 5.37},
#   'visibility': 10000,
#   'pop': 0.03,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2024-06-13 12:00:00'},
#  {'dt': 1718290800,
#   'main': {'temp': 16.53,
#    'feels_like': 15.34,
#    'temp_min': 16.53,
#    'temp_max': 16.53,
#    'pressure': 1017,
#    'sea_level': 1017,
#    'grnd_level': 1012,
#    'humidity': 42,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 92},
#   'wind': {'speed': 3.7, 'deg': 288, 'gust': 4.44},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2024-06-13 15:00:00'},
#  {'dt': 1718301600,
#   'main': {'temp': 16.51,
#    'feels_like': 15.39,
#    'temp_min': 16.51,
#    'temp_max': 16.51,
#    'pressure': 1017,
#    'sea_level': 1017,
#    'grnd_level': 1012,
#    'humidity': 45,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 67},
#   'wind': {'speed': 2.22, 'deg': 308, 'gust': 3.26},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2024-06-13 18:00:00'},
#  {'dt': 1718312400,
#   'main': {'temp': 13.06,
#    'feels_like': 11.86,
#    'temp_min': 13.06,
#    'temp_max': 13.06,
#    'pressure': 1017,
#    'sea_level': 1017,
#    'grnd_level': 1012,
#    'humidity': 55,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'clouds': {'all': 37},
#   'wind': {'speed': 2.21, 'deg': 118, 'gust': 3.08},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2024-06-13 21:00:00'},
#  {'dt': 1718323200,
#   'main': {'temp': 11.74,
#    'feels_like': 10.54,
#    'temp_min': 11.74,
#    'temp_max': 11.74,
#    'pressure': 1016,
#    'sea_level': 1016,
#    'grnd_level': 1011,
#    'humidity': 60,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 60},
#   'wind': {'speed': 2.76, 'deg': 142, 'gust': 5.96},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2024-06-14 00:00:00'},
#  {'dt': 1718334000,
#   'main': {'temp': 11.65,
#    'feels_like': 10.44,
#    'temp_min': 11.65,
#    'temp_max': 11.65,
#    'pressure': 1015,
#    'sea_level': 1015,
#    'grnd_level': 1010,
#    'humidity': 60,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 3.36, 'deg': 144, 'gust': 9.33},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2024-06-14 03:00:00'},
#  {'dt': 1718344800,
#   'main': {'temp': 13.83,
#    'feels_like': 12.78,
#    'temp_min': 13.83,
#    'temp_max': 13.83,
#    'pressure': 1014,
#    'sea_level': 1014,
#    'grnd_level': 1009,
#    'humidity': 58,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 3.76, 'deg': 150, 'gust': 8.83},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2024-06-14 06:00:00'},
#  {'dt': 1718355600,
#   'main': {'temp': 20.1,
#    'feels_like': 19.26,
#    'temp_min': 20.1,
#    'temp_max': 20.1,
#    'pressure': 1013,
#    'sea_level': 1013,
#    'grnd_level': 1008,
#    'humidity': 42,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 4.19, 'deg': 164, 'gust': 5.78},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2024-06-14 09:00:00'},
#  {'dt': 1718366400,
#   'main': {'temp': 20.34,
#    'feels_like': 19.6,
#    'temp_min': 20.34,
#    'temp_max': 20.34,
#    'pressure': 1012,
#    'sea_level': 1012,
#    'grnd_level': 1007,
#    'humidity': 45,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 98},
#   'wind': {'speed': 6.15, 'deg': 208, 'gust': 7.95},
#   'visibility': 10000,
#   'pop': 0.02,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2024-06-14 12:00:00'},
#  {'dt': 1718377200,
#   'main': {'temp': 17.94,
#    'feels_like': 17.46,
#    'temp_min': 17.94,
#    'temp_max': 17.94,
#    'pressure': 1013,
#    'sea_level': 1013,
#    'grnd_level': 1008,
#    'humidity': 64,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': {'all': 98},
#   'wind': {'speed': 3.79, 'deg': 191, 'gust': 6.31},
#   'visibility': 10000,
#   'pop': 0.72,
#   'rain': {'3h': 0.22},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2024-06-14 15:00:00'},
#  {'dt': 1718388000,
#   'main': {'temp': 17.77,
#    'feels_like': 17.35,
#    'temp_min': 17.77,
#    'temp_max': 17.77,
#    'pressure': 1012,
#    'sea_level': 1012,
#    'grnd_level': 1007,
#    'humidity': 67,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 86},
#   'wind': {'speed': 3.37, 'deg': 172, 'gust': 5.81},
#   'visibility': 10000,
#   'pop': 0.65,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2024-06-14 18:00:00'},
#  {'dt': 1718398800,
#   'main': {'temp': 15.2,
#    'feels_like': 14.92,
#    'temp_min': 15.2,
#    'temp_max': 15.2,
#    'pressure': 1012,
#    'sea_level': 1012,
#    'grnd_level': 1007,
#    'humidity': 82,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 83},
#   'wind': {'speed': 2.74, 'deg': 157, 'gust': 6.32},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2024-06-14 21:00:00'},
#  {'dt': 1718409600,
#   'main': {'temp': 13.58,
#    'feels_like': 13.24,
#    'temp_min': 13.58,
#    'temp_max': 13.58,
#    'pressure': 1011,
#    'sea_level': 1011,
#    'grnd_level': 1006,
#    'humidity': 86,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 79},
#   'wind': {'speed': 2.55, 'deg': 168, 'gust': 5.53},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2024-06-15 00:00:00'},
#  {'dt': 1718420400,
#   'main': {'temp': 13.12,
#    'feels_like': 12.73,
#    'temp_min': 13.12,
#    'temp_max': 13.12,
#    'pressure': 1010,
#    'sea_level': 1010,
#    'grnd_level': 1004,
#    'humidity': 86,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 2.74, 'deg': 161, 'gust': 6.93},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2024-06-15 03:00:00'},
#  {'dt': 1718431200,
#   'main': {'temp': 16.44,
#    'feels_like': 15.86,
#    'temp_min': 16.44,
#    'temp_max': 16.44,
#    'pressure': 1007,
#    'sea_level': 1007,
#    'grnd_level': 1002,
#    'humidity': 66,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 4.61, 'deg': 147, 'gust': 9.32},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2024-06-15 06:00:00'},
#  {'dt': 1718442000,
#   'main': {'temp': 21,
#    'feels_like': 20.64,
#    'temp_min': 21,
#    'temp_max': 21,
#    'pressure': 1008,
#    'sea_level': 1008,
#    'grnd_level': 1003,
#    'humidity': 57,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 6.43, 'deg': 225, 'gust': 8.53},
#   'visibility': 10000,
#   'pop': 0.36,
#   'rain': {'3h': 0.23},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2024-06-15 09:00:00'},
#  {'dt': 1718452800,
#   'main': {'temp': 15.31,
#    'feels_like': 15.3,
#    'temp_min': 15.31,
#    'temp_max': 15.31,
#    'pressure': 1009,
#    'sea_level': 1009,
#    'grnd_level': 1004,
#    'humidity': 92,
#    'temp_kf': 0},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 3.2, 'deg': 185, 'gust': 10.98},
#   'visibility': 10000,
#   'pop': 0.98,
#   'rain': {'3h': 5.93},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2024-06-15 12:00:00'},
#  {'dt': 1718463600,
#   'main': {'temp': 18.38,
#    'feels_like': 18.13,
#    'temp_min': 18.38,
#    'temp_max': 18.38,
#    'pressure': 1009,
#    'sea_level': 1009,
#    'grnd_level': 1004,
#    'humidity': 71,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 5.04, 'deg': 226, 'gust': 8.46},
#   'visibility': 10000,
#   'pop': 0.8,
#   'rain': {'3h': 0.5},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2024-06-15 15:00:00'},
#  {'dt': 1718474400,
#   'main': {'temp': 18.02,
#    'feels_like': 17.57,
#    'temp_min': 18.02,
#    'temp_max': 18.02,
#    'pressure': 1009,
#    'sea_level': 1009,
#    'grnd_level': 1004,
#    'humidity': 65,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': {'all': 99},
#   'wind': {'speed': 2.09, 'deg': 231, 'gust': 4.71},
#   'visibility': 10000,
#   'pop': 0.66,
#   'rain': {'3h': 0.11},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2024-06-15 18:00:00'},
#  {'dt': 1718485200,
#   'main': {'temp': 15.28,
#    'feels_like': 14.9,
#    'temp_min': 15.28,
#    'temp_max': 15.28,
#    'pressure': 1011,
#    'sea_level': 1011,
#    'grnd_level': 1006,
#    'humidity': 78,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 81},
#   'wind': {'speed': 2.62, 'deg': 189, 'gust': 7.09},
#   'visibility': 10000,
#   'pop': 0.42,
#   'rain': {'3h': 0.29},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2024-06-15 21:00:00'},
#  {'dt': 1718496000,
#   'main': {'temp': 13.21,
#    'feels_like': 12.81,
#    'temp_min': 13.21,
#    'temp_max': 13.21,
#    'pressure': 1011,
#    'sea_level': 1011,
#    'grnd_level': 1006,
#    'humidity': 85,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 67},
#   'wind': {'speed': 1.58, 'deg': 221, 'gust': 1.77},
#   'visibility': 10000,
#   'pop': 0.22,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2024-06-16 00:00:00'},
#  {'dt': 1718506800,
#   'main': {'temp': 11.98,
#    'feels_like': 11.43,
#    'temp_min': 11.98,
#    'temp_max': 11.98,
#    'pressure': 1011,
#    'sea_level': 1011,
#    'grnd_level': 1006,
#    'humidity': 84,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'clouds': {'all': 46},
#   'wind': {'speed': 2.13, 'deg': 209, 'gust': 3.28},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2024-06-16 03:00:00'},
#  {'dt': 1718517600,
#   'main': {'temp': 16.4,
#    'feels_like': 15.51,
#    'temp_min': 16.4,
#    'temp_max': 16.4,
#    'pressure': 1012,
#    'sea_level': 1012,
#    'grnd_level': 1007,
#    'humidity': 54,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 61},
#   'wind': {'speed': 3.84, 'deg': 226, 'gust': 8.22},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2024-06-16 06:00:00'},
#  {'dt': 1718528400,
#   'main': {'temp': 21.05,
#    'feels_like': 20.23,
#    'temp_min': 21.05,
#    'temp_max': 21.05,
#    'pressure': 1012,
#    'sea_level': 1012,
#    'grnd_level': 1007,
#    'humidity': 39,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'clouds': {'all': 9},
#   'wind': {'speed': 4.86, 'deg': 224, 'gust': 8.14},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2024-06-16 09:00:00'},
#  {'dt': 1718539200,
#   'main': {'temp': 22.53,
#    'feels_like': 21.83,
#    'temp_min': 22.53,
#    'temp_max': 22.53,
#    'pressure': 1012,
#    'sea_level': 1012,
#    'grnd_level': 1007,
#    'humidity': 38,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'clouds': {'all': 28},
#   'wind': {'speed': 4.86, 'deg': 226, 'gust': 7.86},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2024-06-16 12:00:00'},
#  {'dt': 1718550000,
#   'main': {'temp': 20.97,
#    'feels_like': 20.35,
#    'temp_min': 20.97,
#    'temp_max': 20.97,
#    'pressure': 1012,
#    'sea_level': 1012,
#    'grnd_level': 1007,
#    'humidity': 47,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 94},
#   'wind': {'speed': 4.5, 'deg': 217, 'gust': 6.72},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2024-06-16 15:00:00'},
#  {'dt': 1718560800,
#   'main': {'temp': 19.83,
#    'feels_like': 19.25,
#    'temp_min': 19.83,
#    'temp_max': 19.83,
#    'pressure': 1013,
#    'sea_level': 1013,
#    'grnd_level': 1008,
#    'humidity': 53,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 89},
#   'wind': {'speed': 2.84, 'deg': 196, 'gust': 6.2},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2024-06-16 18:00:00'},
#  {'dt': 1718571600,
#   'main': {'temp': 16.94,
#    'feels_like': 16.41,
#    'temp_min': 16.94,
#    'temp_max': 16.94,
#    'pressure': 1014,
#    'sea_level': 1014,
#    'grnd_level': 1009,
#    'humidity': 66,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 59},
#   'wind': {'speed': 2.49, 'deg': 201, 'gust': 6.2},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2024-06-16 21:00:00'},
#  {'dt': 1718582400,
#   'main': {'temp': 15.45,
#    'feels_like': 14.88,
#    'temp_min': 15.45,
#    'temp_max': 15.45,
#    'pressure': 1015,
#    'sea_level': 1015,
#    'grnd_level': 1010,
#    'humidity': 70,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 76},
#   'wind': {'speed': 2.23, 'deg': 205, 'gust': 4.84},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2024-06-17 00:00:00'},
#  {'dt': 1718593200,
#   'main': {'temp': 14.49,
#    'feels_like': 13.93,
#    'temp_min': 14.49,
#    'temp_max': 14.49,
#    'pressure': 1015,
#    'sea_level': 1015,
#    'grnd_level': 1010,
#    'humidity': 74,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 99},
#   'wind': {'speed': 2.41, 'deg': 187, 'gust': 5.38},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2024-06-17 03:00:00'},
#  {'dt': 1718604000,
#   'main': {'temp': 18.68,
#    'feels_like': 18.14,
#    'temp_min': 18.68,
#    'temp_max': 18.68,
#    'pressure': 1015,
#    'sea_level': 1015,
#    'grnd_level': 1010,
#    'humidity': 59,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 54},
#   'wind': {'speed': 3.62, 'deg': 188, 'gust': 6.55},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2024-06-17 06:00:00'},
#  {'dt': 1718614800,
#   'main': {'temp': 24.15,
#    'feels_like': 23.72,
#    'temp_min': 24.15,
#    'temp_max': 24.15,
#    'pressure': 1015,
#    'sea_level': 1015,
#    'grnd_level': 1010,
#    'humidity': 42,
#    'temp_kf': 0},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'clouds': {'all': 13},
#   'wind': {'speed': 4.56, 'deg': 206, 'gust': 6.86},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2024-06-17 09:00:00'},
#  {'dt': 1718625600,
#   'main': {'temp': 27.38,
#    'feels_like': 26.84,
#    'temp_min': 27.38,
#    'temp_max': 27.38,
#    'pressure': 1014,
#    'sea_level': 1014,
#    'grnd_level': 1009,
#    'humidity': 34,
#    'temp_kf': 0},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'clouds': {'all': 20},
#   'wind': {'speed': 4.88, 'deg': 207, 'gust': 7.57},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2024-06-17 12:00:00'}]

# %% [markdown]
# Looks like the information we'll want is in `list`. Let's look at the first element of `list` to investigate further.

# %%
json["list"][0]
# Out:
# {'dt': 1718204400,
#  'main': {'temp': 17.32,
#   'feels_like': 16.52,
#   'temp_min': 17.32,
#   'temp_max': 18.04,
#   'pressure': 1009,
#   'sea_level': 1009,
#   'grnd_level': 1011,
#   'humidity': 54,
#   'temp_kf': -0.72},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03d'}],
#  'clouds': {'all': 25},
#  'wind': {'speed': 4.47, 'deg': 254, 'gust': 6.42},
#  'visibility': 10000,
#  'pop': 0.03,
#  'sys': {'pod': 'd'},
#  'dt_txt': '2024-06-12 15:00:00'}

# %%
json["city"]
# Out:
# {'id': 6545310,
#  'name': 'Mitte',
#  'coord': {'lat': 52.52, 'lon': 13.405},
#  'country': 'DE',
#  'population': 329078,
#  'timezone': 7200,
#  'sunrise': 1718160203,
#  'sunset': 1718220562}

# %% [markdown]
# # Building a DataFrame

# %% [markdown]
# ## What would we like from the json?
# Let's begin by exploring the first 2 items of `list` and see what we have.

# %%
json["list"][0]
# Out:
# {'dt': 1718204400,
#  'main': {'temp': 17.32,
#   'feels_like': 16.52,
#   'temp_min': 17.32,
#   'temp_max': 18.04,
#   'pressure': 1009,
#   'sea_level': 1009,
#   'grnd_level': 1011,
#   'humidity': 54,
#   'temp_kf': -0.72},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03d'}],
#  'clouds': {'all': 25},
#  'wind': {'speed': 4.47, 'deg': 254, 'gust': 6.42},
#  'visibility': 10000,
#  'pop': 0.03,
#  'sys': {'pod': 'd'},
#  'dt_txt': '2024-06-12 15:00:00'}

# %%
json["list"][1]
# Out:
# {'dt': 1718215200,
#  'main': {'temp': 16.25,
#   'feels_like': 15.31,
#   'temp_min': 15.89,
#   'temp_max': 16.25,
#   'pressure': 1012,
#   'sea_level': 1012,
#   'grnd_level': 1011,
#   'humidity': 53,
#   'temp_kf': 0.36},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'clouds': {'all': 53},
#  'wind': {'speed': 2.79, 'deg': 279, 'gust': 4.6},
#  'visibility': 10000,
#  'pop': 0.07,
#  'sys': {'pod': 'd'},
#  'dt_txt': '2024-06-12 18:00:00'}

# %% [markdown]
# When deciding what is useful, remember the project goals.
#
# The time the forecast is for will be useful.

# %%
json["list"][0]["dt_txt"]
# Out:
# '2024-06-12 15:00:00'

# %% [markdown]
# The temperature will be useful. Scooters don't have heaters!

# %%
json["list"][0]["main"]["temp"]
# Out:
# 17.32

# %% [markdown]
# The forecast will be useful. Scooters don't have a roof!

# %%
json["list"][0]["weather"][0]["main"]
# Out:
# 'Clouds'

# %% [markdown]
# If it's been recently raining will be useful. Wet conditions will affect scooter rentals.

# %%
json["list"][0]["rain"]["3h"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-7bf1b96bfefc> in <cell line: 1>()
# ----> 1 json["list"][0]["rain"]["3h"]
#
# KeyError: 'rain'

# %% [markdown]
# > If you get an error on 'rain', it's because it hasn't rained in the last 3 hours. But we know this key exists, because we read the [docs](https://openweathermap.org/forecast5)

# %% [markdown]
# Wind speed will be useful. It's likely to affect whether people rent scooters or not.

# %%
json["list"][0]["wind"]["speed"]
# Out:
# 4.47

# %% [markdown]
# ## Bringing together our chosen items

# %%
weather_items = []

for item in json["list"]:
    weather_item = {
        "forecast_time": item.get("dt_txt", None),
        "temperature": item["main"].get("temp", None),
        "forecast": item["weather"][0].get("main", None),
        "rain_in_last_3h": item.get("rain", {}).get("3h", 0),
        "wind_speed": item["wind"].get("speed", None),
    }

    weather_items.append(weather_item)

weather_df = pd.DataFrame(weather_items)

weather_df.head()
# Out:
#          forecast_time  temperature forecast  rain_in_last_3h  wind_speed
# 0  2024-06-12 15:00:00        17.32   Clouds              0.0        4.47
# 1  2024-06-12 18:00:00        16.25   Clouds              0.0        2.79
# 2  2024-06-12 21:00:00        12.20    Clear              0.0        2.33
# 3  2024-06-13 00:00:00        10.13   Clouds              0.0        2.62
# 4  2024-06-13 03:00:00         9.06   Clouds              0.0        2.59

# %% [markdown]
# The `rain` key in the JSON data is not always present. In the absence of this key, it's assumed that there hasn't been any recent rainfall. Since this key isn't always available, not encountering it during our loop can cause an error. To address this, we'll employ two `.get()` methods to handle the absence of the `rain` key.
#
# > **Remember:** The second parameter of `.get()` serves as a fallback value, which is inserted into our dictionary if the key we're looking for doesn't exist.
#
# The first `.get()` method checks for the existence of the `rain` key. If present, it will use the value associated with that key. If the `rain` key is missing, an empty dictionary will be used, preventing the code from breaking. The second `.get()` method checks for the `3h` key. If present, it will use its value. Otherwise, a default value of `0` will be used.

# %% [markdown]
# # Creating a function for multiple cities

# %%
import pandas as pd
from datetime import datetime
from pytz import timezone

def fetch_weather_data(cities):
  # Let's ensure the timezone is our local timezone
  berlin_timezone = timezone('Europe/Berlin')
  API_key = userdata.get('openWeatherApi')
  weather_items = []

  for city in cities:

    country = "DE"

    # Geocoder api to get the latitude and longitude
    # This information should be from your SQL table, but we don't have that here
    geo_url = (f"http://api.openweathermap.org/geo/1.0/direct?q={city},{country}&limit=5&appid={API_key}")
    geo_response = requests.get(geo_url)
    geo_json = geo_response.json()
    latitude = geo_json[0]["lat"]
    longitude = geo_json[0]["lon"]

    # weather api
    weather_url = (f"https://api.openweathermap.org/data/2.5/forecast?lat={latitude}&lon={longitude}&appid={API_key}&units=metric")
    weather_response = requests.get(weather_url)
    weather_json = weather_response.json()

    # Added the time retrieved so we know when the forecast was made
    retrieval_time = datetime.now(berlin_timezone).strftime("%Y-%m-%d %H:%M:%S")

    for item in weather_json["list"]:
        weather_item = {
            # Added the city name, so the information is clear when looking at multiple cities
            "city": city,
            "forecast_time": item.get("dt_txt", None),
            "temperature": item["main"].get("temp", None),
            "forecast": item["weather"][0].get("main", None),
            "rain_in_last_3h": item.get("rain", {}).get("3h", 0),
            "wind_speed": item["wind"].get("speed", None),
            "data_retrieved_at": retrieval_time
        }

        weather_items.append(weather_item)

  weather_df = pd.DataFrame(weather_items)

  return weather_df

# %%
fetch_weather_data(["Berlin", "Hamburg", "Munich"])
# Out:
#        city        forecast_time  temperature forecast  rain_in_last_3h  \
# 0    Berlin  2024-06-12 15:00:00        16.88   Clouds              0.0
# 1    Berlin  2024-06-12 18:00:00        16.03   Clouds              0.0
# 2    Berlin  2024-06-12 21:00:00        12.35    Clear              0.0
# 3    Berlin  2024-06-13 00:00:00        10.36   Clouds              0.0
# 4    Berlin  2024-06-13 03:00:00         9.34   Clouds              0.0
# ..      ...                  ...          ...      ...              ...
# 115  Munich  2024-06-17 00:00:00        14.49   Clouds              0.0
# 116  Munich  2024-06-17 03:00:00        13.87   Clouds              0.0
# 117  Munich  2024-06-17 06:00:00        16.26   Clouds              0.0
# 118  Munich  2024-06-17 09:00:00        22.13   Clouds              0.0
# 119  Munich  2024-06-17 12:00:00        24.45   Clouds              0.0
#
#      wind_speed    data_retrieved_at
# 0          4.72  2024-06-12 14:48:18
# 1          2.98  2024-06-12 14:48:18
# 2          2.26  2024-06-12 14:48:18
# 3          2.60  2024-06-12 14:48:18
# 4          2.66  2024-06-12 14:48:18
# ..          ...                  ...
# 115        1.83  2024-06-12 14:48:20
# 116        1.59  2024-06-12 14:48:20
# 117        1.45  2024-06-12 14:48:20
# 118        1.84  2024-06-12 14:48:20
# 119        2.95  2024-06-12 14:48:20
#
# [120 rows x 7 columns]

# %% [markdown]
# # Making our function work with our SQL cities data
# This section delves into a more advanced aspect of the project, which may be beyond the point many of you got to. However, it serves as an illustrative example of how to structure your work effectively. It demonstrates how we can compartmentalise various aspects of our data processing pipeline into distinct functions, enhancing code readability and facilitating debugging.
# > This part will only work locally, not on colab. You must also create your weather table in SQL first.

# %%
import pandas as pd
import requests
from pytz import timezone
from datetime import datetime

def retrieve_and_send_data():
  connection_string = create_connection_string()
  cities_df = fetch_cities_data(connection_string)
  weather_df = fetch_weather_data(cities_df)
  store_weather_data(weather_df, connection_string)
  return "Data has been updated"

def create_connection_string():
  schema = "gans"
  host = "127.0.0.1"
  user = "root"
  password = "YOUR_PASSWORD_HERE"
  port = 3306
  return f'mysql+pymysql://{user}:{password}@{host}:{port}/{schema}'

def fetch_cities_data(connection_string):
  return pd.read_sql("cities", con=connection_string)

def fetch_weather_data(cities_df):
  berlin_timezone = timezone('Europe/Berlin')
  API_key = 'YOUR_API_HERE'
  weather_items = []

  for _, city in cities_df.iterrows():
      latitude = city["latitude"]
      longitude = city["longitude"]
      city_id = city["city_id"]

      url = (f"https://api.openweathermap.org/data/2.5/forecast?lat={latitude}&lon={longitude}&appid={API_key}&units=metric")
      response = requests.get(url)
      weather_data = response.json()

      retrieval_time = datetime.now(berlin_timezone).strftime("%Y-%m-%d %H:%M:%S")

      for item in weather_data["list"]:
          weather_item = {
              "city_id": city_id,
              "forecast_time": item.get("dt_txt"),
              "temperature": item["main"].get("temp"),
              "forecast": item["weather"][0].get("main"),
              "rain_in_last_3h": item.get("rain", {}).get("3h", 0),
              "wind_speed": item["wind"].get("speed"),
              "data_retrieved_at": retrieval_time
          }
          weather_items.append(weather_item)

  weather_df = pd.DataFrame(weather_items)
  weather_df["forecast_time"] = pd.to_datetime(weather_df["forecast_time"])
  weather_df["data_retrieved_at"] = pd.to_datetime(weather_df["data_retrieved_at"])

  return weather_df

def store_weather_data(weather_df, connection_string):
  weather_df.to_sql('weather',
                    if_exists='append',
                    con=connection_string,
                    index=False)

# %%
retrieve_and_send_data()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-27-ba030d223455> in <cell line: 1>()
# ----> 1 retreiving_and_sending_data()
#
# <ipython-input-26-3ab2d88892b4> in retreiving_and_sending_data()
#       6 def retreiving_and_sending_data():
#       7   connection_string = connection()
# ----> 8   cities_df = get_cities_data(connection_string)
#       9   weather_df = get_weather_data(cities_df)
#      10   send_weather_data(weather_df, connection_string)
#
# <ipython-input-26-3ab2d88892b4> in get_cities_data(connection_string)
#      20
#      21 def get_cities_data(connection_string):
# ---> 22   return pd.read_sql("cities", con=connection_string)
#      23
#      24 def get_weather_data(cities_df):
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     631         dtype_backend = "numpy"  # type: ignore[assignment]
#     632
# --> 633     with pandasSQL_builder(con) as pandas_sql:
#     634         if isinstance(pandas_sql, SQLiteDatabase):
#     635             return pandas_sql.read_query(
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in pandasSQL_builder(con, schema, need_transaction)
#     830
#     831     if sqlalchemy is not None and isinstance(con, (str, sqlalchemy.engine.Connectable)):
# --> 832         return SQLDatabase(con, schema, need_transaction)
#     833
#     834     warnings.warn(
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in __init__(self, con, schema, need_transaction)
#    1534         self.exit_stack = ExitStack()
#    1535         if isinstance(con, str):
# -> 1536             con = create_engine(con)
#    1537             self.exit_stack.callback(con.dispose)
#    1538         if isinstance(con, Engine):
#
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/create.py in create_engine(url, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/util/deprecations.py in warned(fn, *args, **kwargs)
#     279                         stacklevel=3,
#     280                     )
# --> 281             return fn(*args, **kwargs)  # type: ignore[no-any-return]
#     282
#     283         doc = fn.__doc__ is not None and fn.__doc__ or ""
#
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/create.py in create_engine(url, **kwargs)
#     597             if k in kwargs:
#     598                 dbapi_args[k] = pop_kwarg(k)
# --> 599         dbapi = dbapi_meth(**dbapi_args)
#     600
#     601     dialect_args["dbapi"] = dbapi
#
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/dialects/mysql/pymysql.py in import_dbapi(cls)
#      73     @classmethod
#      74     def import_dbapi(cls):
# ---> 75         return __import__("pymysql")
#      76
#      77     @langhelpers.memoized_property
#
# ModuleNotFoundError: No module named 'pymysql'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
